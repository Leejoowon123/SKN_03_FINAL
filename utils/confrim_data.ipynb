# %%
import pandas as pd

# %%
final_path = "C:/SKN_3_MyProject/SKN_03_FINAL/Data/Final"

# %%
df = pd.read_json(f"{final_path}/merged_output.json",lines=True)

# %%
test_df = df.copy()

# %%
# "percentage" 컬럼을 숫자 형식으로 변환
test_df["percentage"] = pd.to_numeric(test_df["percentage"], errors="coerce")

# "percentage" 값이 100을 초과하는 행 필터링
filtered_df = test_df[test_df["percentage"] > 100]

# %%
filtered_df
# Out:
#                title start_date_x  end_date_x           place_x  \
# 19   ACC 퍼니, 빨래 [광주]   2024.03.22  2024.03.24   국립아시아문화전당 (극장2)
# 182   바다로 간 쓰레기 [인천]   2023.11.25  2023.11.25  인천동구문화체육센터 (공연장)
# 485             천로역정   2023.12.09  2024.12.28     명륜아트홀 (명륜아트홀)
#
#                                    cast          editor runtime       age  \
# 19   신고은, 노희찬, 강나리, 김송이, 이강혁, 안두호, 박정민   추민주, 민찬홍, 최세연     2:45  만 12세 이상
# 182             정영민, 이희준, 황미선, 송희근, 이선호  김범수, 류완선, 신수경     0:55   만 4세 이상
# 485  임미영, 이나영, 서태경, 김지혜, 김성호, 박상하, 박민규   이수함, 김은지, 김창대     1:40   만 9세 이상
#
#       producer         host  ...           genre  \
# 19   (주)씨에이치수박    국립아시아문화전당  ...          코미디/유머
# 182     극단 미추홀        인천광역시  ...  드라마/감동, 코미디/유머
# 485       조이피플  명륜아트홀, 조이피플  ...          드라마/감동
#
#                                                  story  \
# 19   세탁소 직원들이 벌이는 유쾌한 사건들을 통해 사랑과 우정의 가치를 담은 이야기. 세...
# 182  인천 동구의 문화체육센터에서 열리는 뮤지컬 '바다로 간 쓰레기'는 쓰레기 문제에 대...
# ...
