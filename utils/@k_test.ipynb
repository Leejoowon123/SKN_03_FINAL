# %%
import os
print(os.path.abspath(os.path.join(os.getcwd(), '..')))
# Out:
# c:\SKN_3_MyProject\SKN_03_FINAL

# %%
import sys
sys.path.append(os.path.join(os.getcwd(), 'utils'))
sys.path.append(os.path.join(os.getcwd(), '..'))

# %%
from tensorflow.keras.models import load_model
import sys
import os
import config

# 사용자 정의 레이어와 손실 함수 등록
from utils.DeepFM import FMInteraction, weighted_loss  # FMInteraction과 weighted_loss가 정의된 파일에서 가져오기

# 모델 로드 시 custom_objects에 사용자 정의 객체 추가
model = load_model(config.save_model_path, 
                   custom_objects={'FMInteraction': FMInteraction, 'weighted_loss': weighted_loss})
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# %% [markdown]
# # 범주형 자료만 (코드)

# %% [markdown]
# # 연속형 자료 (모델)

# %%
class MusicalRecommender:
    def __init__(self):
        self.data = None
        self.original_data = None
        self.model = None
        self.label_encoders = {}
    
    def load_and_preprocess_data(self):
        # 데이터 로드 및 전처리
        self.data = pd.read_json(config.df_with_negatives_path, lines=True)  # Update the path to a relative one if necessary
        self.original_data = self.data.copy()
        
        categorical_features = ['title', 
                                'cast', 
                                'genre'
                                ]
        
        # 범주형 변수 레이블 인코딩
        for feature in categorical_features:
            self.label_encoders[feature] = LabelEncoder()
            self.data[feature] = self.label_encoders[feature].fit_transform(self.data[feature].astype(str))


    def recommend_for_cast(self, cast_name, top_n=10):
        # 1. 캐스트 이름을 인코딩
        if cast_name not in self.label_encoders['cast'].classes_:
            print(f"Error: {cast_name} is not in the dataset.")
            return []
        
        cast_encoded = self.label_encoders['cast'].transform([cast_name])[0]
        
        # 2. 전체 뮤지컬 후보 생성
        musical_candidates = self.original_data[['title', 
                                                 'genre',
                                                #  'percentage', 
                                                #  'ticket_price'
                                                ]].drop_duplicates()
        musical_candidates['cast'] = cast_encoded  # 모든 뮤지컬에 해당 캐스트를 넣음
        
        # 3. 모델 입력 데이터 준비
        input_data = {
            'title': self.label_encoders['title'].transform(musical_candidates['title']),
            'cast': musical_candidates['cast'],
            'genre': self.label_encoders['genre'].transform(musical_candidates['genre']),
            # 'percentage' : musical_candidates['percentage'],
            # 'ticket_price' : musical_candidates['ticket_price']
        }
        
        # 4. 예측 점수 계산
        predictions = model.predict([
            input_data['title'],
            input_data['cast'],
            input_data['genre'],
            # input_data['percentage'],
            # input_data['ticket_price']
        ])
        
        # 5. 점수 조정
        musical_candidates['score'] = predictions
        # 5. 상위 N개 추천
        top_recommendations = musical_candidates.sort_values(by='score', ascending=False).head(top_n)
        
        # 6. 디코딩된 값으로 반환
        top_recommendations['cast'] = self.label_encoders['cast'].inverse_transform(top_recommendations['cast'])
        
        return top_recommendations[['cast', 'title', 'score']]

# %%
recommender = MusicalRecommender()
recommender.load_and_preprocess_data()
# 학습된 모델 로드
# recommender.load_model("C:/SKN_3_MyProject/SKN_03_FINAL/Data/Model/Recommend.h5")

# %%
data = pd.read_json(config.df_with_negatives_path, lines=True)

# %%
# Step 1: cast 유니크 값
unique_cast_names = data['cast'].unique()

# Step 2: 담을 데이터
all_recommendations = []

# %%
# top_n 갯수 설정
top_n = 10

# %%
for cast_name in unique_cast_names:
    recommendations = recommender.recommend_for_cast(cast_name, top_n)
    if not recommendations.empty:
        all_recommendations.append(recommendations)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#  1/45 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# c:\SKN_3_MyProject\.venv\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['title', 'cast', 'genre']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step

# %%
recommendations_df = pd.concat(all_recommendations, ignore_index=True)

# %%
# 배우수
len(unique_cast_names)
# Out:
# 408

# %%
# # Unique한 점수 값들
# unique_scores = recommendations_df['score'].unique()
# print("Unique scores:", unique_scores)

# %%
merged_df = recommendations_df.merge(data, on=['cast', 'title'], how='inner')

# Filter rows where target == 1 in the data DataFrame
target_1_count = merged_df[merged_df['target'] == 1].shape[0]

# Print the count of rows where target == 1
print("Number of matching rows where target is 1:", target_1_count)
# Out:
# Number of matching rows where target is 1: 49

# %%
merged_df
# Out:
#    cast                                              title     score  genre  \
# 0   류정한                            10주년 기념공연, 레베카 [서울(앵콜)]  0.999960     가족
# 1   오만석                            10주년 기념공연, 레베카 [서울(앵콜)]  0.999987     가족
# 2   신영숙                            10주년 기념공연, 레베카 [서울(앵콜)]  0.999987     가족
# 3   장은아                                                헤드윅  0.999966    대학로
# 4   홍지민                                         온스테이지 [정읍]  0.999986  지역|창작
# 5    정민                                             라흐마니노프  0.999966     역사
# 6   홍지수                  제17회 DIMF 창작지원작, The Tempest [대구]  0.999823     신화
# 7   김태윤                                     나도 해피엔딩을 쓰고 싶어  0.999957    대학로
# 8   송원근                      Via Air Mail (비아 에어 메일) [대학로]  0.999944    대학로
# 9   성태준                      Via Air Mail (비아 에어 메일) [대학로]  0.999905    대학로
# 10  임예진                      Via Air Mail (비아 에어 메일) [대학로]  0.999978    대학로
# 11  김수하                       틱틱붐: LOUDER THAN WORDS! 쇼케이스  0.999926    대학로
# 12  전원주                                        가시나무 새 [동해]  0.999917     역사
# 13  신성민                                           레드북 [부산]  0.999950  지역|창작
# 14  신성민                                           레드북 [고양]  0.999923  지역|창작
# 15  황두현  창작뮤지컬어워드 NEXT, 니에블라 & 죽거나, 죽이거나 & Behind the Moon  0.999931    대학로
# 16  황두현                                              바톤콘서트  0.999904    대학로
# 17  김경수                                      키다리 아저씨 [대학로]  0.999968     가족
# 18  이지수  창작뮤지컬어워드 NEXT, 니에블라 & 죽거나, 죽이거나 & Behind the Moon  0.999975    대학로
# 19  최인형                                    신과 함께: 저승편 [김해]  0.999934     신화
# 20  서연정                                    신과 함께: 저승편 [김해]  0.999905     신화
# 21  금승훈                                    신과 함께: 저승편 [김해]  0.999945     신화
# 22  김대웅                       틱틱붐: LOUDER THAN WORDS! 쇼케이스  0.999903    대학로
# 23  이동규                                        다윈 영의 악의 기원  0.999864     역사
# 24  한보라                                           레드북 [부산]  0.999981  지역|창작
# 25  이아진  창작뮤지컬어워드 NEXT, 니에블라 & 죽거나, 죽이거나 & Behind the Moon  0.999934    대학로
# 26  임진섭                   여신님이 보고 계셔 10th Anniversary [부산]  0.999983     가족
# 27  윤태호                                    신과 함께: 저승편 [김해]  0.999834     신화
# 28  곽수민                  제17회 DIMF 창작지원작, The Tempest [대구]  0.999957     신화
# 29  김유진                                          싯다르타 [울산]  0.999905     신화
# 30  조풍래  창작뮤지컬어워드 NEXT, 니에블라 & 죽거나, 죽이거나 & Behind the Moon  0.999932    대학로
# 31  조풍래                                           레드북 [고양]  0.999928  지역|창작
# 32  전동석                                                헤드윅  0.999909    대학로
# 33  문지수                               육영수, 그 시절의 아카시아 [대구]  0.999967     역사
# 34  김성규                                           레드북 [부산]  0.999930  지역|창작
# 35  이지숙                                  집들이 콘서트, #38. 로기수  0.999919    대학로
# 36  박진주                                           레드북 [부산]  0.999872  지역|창작
# 37  이해준                       틱틱붐: LOUDER THAN WORDS! 쇼케이스  0.999963    대학로
# 38  신민호                               육영수, 그 시절의 아카시아 [대구]  0.999930     역사
# 39  김청아                    제8회 한국뮤지컬어워즈, 뮤이어(MU:Year) 스테이지  0.999918    대학로
# 40  양동혁                               육영수, 그 시절의 아카시아 [대구]  0.999885     역사
# 41  김가람                                     삼거리 슈퍼스타 [대학로]  0.999965    대학로
# 42  조동연                                     삼거리 슈퍼스타 [대학로]  0.999932    대학로
# 43  박장현                                              할란카운티  0.999963  지역|창작
# 44  권성찬                                    예수 그리스도, 더바이블 Ⅱ  0.999853     역사
# 45  양희준                       틱틱붐: LOUDER THAN WORDS! 쇼케이스  0.999928    대학로
# 46  김하준                                               왓 이프  0.999909     가족
# 47  김민강                                        인간탐구생활 [영천]  0.999959  지역|창작
# 48  임태경                                              할란카운티  0.999962  지역|창작
#
#     percentage ticket_price  target
# 0       0.6673        0.734       1
# 1       0.6673        0.734       1
# 2       0.6673        0.734       1
# 3       0.7885       0.6749       1
# 4       0.9855       0.0838       1
# 5       0.3383       0.3419       1
# 6          NaN       0.2315       1
# 7       0.0763       0.3202       1
# 8       0.3745       0.3498       1
# 9       0.3745       0.3498       1
# 10      0.3745       0.3498       1
# 11      0.9735       0.1133       1
# 12      0.3625       0.0542       1
# 13      0.4859       0.6323       1
# 14      0.3714       0.5172       1
# 15      0.5980       0.0542       1
# 16      0.4657       0.3852       1
# 17      0.4934       0.3793       1
# 18      0.5980       0.0542       1
# 19         NaN       0.2907       1
# 20         NaN       0.2907       1
# 21         NaN       0.2907       1
# 22      0.9735       0.1133       1
# 23      0.2565       0.3498       1
# 24      0.4859       0.6323       1
# 25      0.5980       0.0542       1
# 26      0.3671       0.4503       1
# 27         NaN       0.2907       1
# 28         NaN       0.2315       1
# 29         NaN       0.5271       1
# 30      0.5980       0.0542       1
# 31      0.3714       0.5172       1
# 32      0.7885       0.6749       1
# 33         NaN       0.4089       1
# 34      0.4859       0.6323       1
# 35      0.4520       0.3527       1
# 36      0.4859       0.6323       1
# 37      0.9735       0.1133       1
# 38         NaN       0.4089       1
# 39      0.0853       0.1902       1
# 40         NaN       0.4089       1
# 41         NaN       0.2315       1
# 42         NaN       0.2315       1
# 43      0.2820       0.6749       1
# 44         NaN       0.2907       1
# 45      0.9735       0.1133       1
# 46         NaN       0.2907       1
# 47         NaN       0.0542       1
# 48      0.2820       0.6749       1

# %%
# Step 7: 전체 Ground Truth (target=1) 개수
total_target_1_count = data[data['target'] == 1].shape[0]
total_target_1_count
# Out:
# 4182

# %%
# Step 8: Recall@10 계산
recall_golbangE_10 = target_1_count / total_target_1_count

# Step 9: Precision@10 계산
precision_golbangE_10 = target_1_count / (10 * len(unique_cast_names))

golbange_K = target_1_count / (10 * len(unique_cast_names))

# 결과 출력
print(f"Recall@10: {recall_golbangE_10:.4f}")
print(f"Precision@10: {precision_golbangE_10:.4f}")
print(f'@K: {golbange_K: .4f}')
# Out:
# Recall@10: 0.0117
# Precision@10: 0.0120
# @K:  0.0120

# %%
# 10710 / 10 = a = 1071
# L = 10710개에서 target값이 1인 것 개수
# L / (10 * a) = 평가값

# 해당 Cast가 title에 Target 값이 1인 것 갯수/K(추천수 = 10)
# 전체 cast의 값을 저장
# 다 더한 값 / cast
# = 그거다
# 나 못해~ 머리로 짜

# %% [markdown]
# ## Recall@4, Precision@4
#
# - Recall@10=
#     추천된 10개 중 target=1인 실제 관련 항목 수 / 전체 target=1 항목 수 (Ground Truth)
#  - Precision@10=
#     추천된 10개 중 target=1인 실제 관련 항목 수 / 10

# %%
recommender = MusicalRecommender()
recommender.load_and_preprocess_data()

# %%
# Step 1: actor와 genre의 조합 생성
unique_cast_names = data['cast'].unique()
# Step 2: 추천 결과를 담을 데이터
all_recommendations = []

# %%
top_n = 4
# Step 2: 추천 결과를 담을 데이터
all_recommendations = []
for cast_name in unique_cast_names:
    recommendations = recommender.recommend_for_cast(cast_name, top_n)
    if not recommendations.empty:
        all_recommendations.append(recommendations)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step

# %%
recommendations_df_4 = pd.concat(all_recommendations, ignore_index=True)

# %%
recommendations_df_4
# Out:
#      cast                             title     score
# 0     류정한  여신님이 보고 계셔 10th Anniversary [부산]  0.999967
# 1     류정한                            원스 어게인  0.999966
# 2     류정한                     키다리 아저씨 [대학로]  0.999965
# 3     류정한                               데미안  0.999965
# 4     민영기              육영수, 그 시절의 아카시아 [대구]  0.999990
# ...   ...                               ...       ...
# 1627  박중리        제18회 DIMF 창작지원작, 시지프스 [대구]  0.999966
# 1628   조흠                             할란카운티  0.999948
# 1629   조흠                          레드북 [부산]  0.999946
# 1630   조흠                          배니싱 [안양]  0.999938
# 1631   조흠        제18회 DIMF 창작지원작, 시지프스 [대구]  0.999933
#
# [1632 rows x 3 columns]

# %%
# unique_scores = recommendations_df_4['score'].unique()
# print("Unique scores:", unique_scores)

# %%
merged_df_4 = recommendations_df_4.merge(data, on=['cast', 'title'], how='inner')

# Filter rows where target == 1 in the data DataFrame
target_1_count_4 = merged_df_4[merged_df_4['target'] == 1].shape[0]

# Print the count of rows where target == 1
print("Number of matching rows where target is 1:", target_1_count_4)
# Out:
# Number of matching rows where target is 1: 16

# %%
# Step 7: 전체 Ground Truth (target=1) 개수
total_target_1_count_4 = data[data['target'] == 1].shape[0]
total_target_1_count_4
# Out:
# 4182

# %%
# Step 8: Recall@10 계산
recall_golbangE_10 = target_1_count_4 / total_target_1_count_4

# Step 9: Precision@10 계산
precision_golbangE_10 = target_1_count_4 / (4 * len(unique_cast_names))

golbange_K = target_1_count_4 / (4 * len(unique_cast_names))

# 결과 출력
print(f"Recall@4: {recall_golbangE_10:.4f}")
print(f"Precision@4: {precision_golbangE_10:.4f}")
print(f'@K: {golbange_K: .4f}')
# Out:
# Recall@4: 0.0038
# Precision@4: 0.0098
# @K:  0.0098

# %% [markdown]
# ## 유명 배우만 찍어보기

# %%
cast_name = ["정선아", "이정열", "민우혁", "양준모", 
             "이해준", "김도형", "윤형렬", "류정한",
             "박규원", "신영숙", "박우빈" ] # 예시 캐스트 이름
top_n = 4 # 추천할 상위 10개 뮤지컬

# %%
# 추천 결과를 저장할 딕셔너리
recommendations = {}

# 각 배우 이름에 대해 함수 호출
for name in cast_name:
    # recommender.recommend_for_cast를 각 이름에 대해 호출
    result = recommender.recommend_for_cast([name], top_n)
    
    # 반환된 결과를 적절히 처리 (리스트 형태로 변환)
    if isinstance(result, pd.DataFrame):  # 결과가 DataFrame인 경우
        recommendations[name] = result.to_dict(orient='records')  # 레코드 리스트로 변환
    else:
        recommendations[name] = result  # 리스트나 다른 형식일 경우 그대로 저장
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# c:\SKN_3_MyProject\.venv\Lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# c:\SKN_3_MyProject\.venv\Lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# c:\SKN_3_MyProject\.venv\Lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# c:\SKN_3_MyProject\.venv\Lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# c:\SKN_3_MyProject\.venv\Lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# c:\SKN_3_MyProject\.venv\Lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 22/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# c:\SKN_3_MyProject\.venv\Lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# c:\SKN_3_MyProject\.venv\Lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step
#  1/45 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# c:\SKN_3_MyProject\.venv\Lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# c:\SKN_3_MyProject\.venv\Lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# Error: ['박우빈'] is not in the dataset.

# %%
recommendation_list = []
for cast, musicals in recommendations.items():
    for musical in musicals:
        recommendation_list.append(musical)

df_recommendations = pd.DataFrame(recommendation_list)

# %%
# unique_scores = df_recommendations['score'].unique()
# print("Unique scores:", unique_scores)

# %%
merged_df_4 = df_recommendations.merge(data, on=['cast', 'title'], how='inner')

# %%
# Filter rows where target == 1 in the data DataFrame
target_1_count_4 = merged_df_4[merged_df_4['target'] == 1].shape[0]

# %%
# Print the count of rows where target == 1
print("Number of matching rows where target is 1:", target_1_count_4)
# Out:
# Number of matching rows where target is 1: 1

# %%
merged_df_4
# Out:
#   cast                         title     score genre  percentage ticket_price  \
# 0  이해준  틱틱붐: LOUDER THAN WORDS! 쇼케이스  0.999963   대학로      0.9735       0.1133
#
#    target
# 0       1

# %%
# Step 8: Recall@10 계산
recall_golbangE_10 = target_1_count_4 / total_target_1_count_4

# Step 9: Precision@10 계산
precision_golbangE_10 = target_1_count_4 / (4 * len(unique_cast_names))

golbange_K = target_1_count_4 / (4 * len(unique_cast_names))

# 결과 출력
print(f"Recall@4: {recall_golbangE_10:.4f}")
print(f"Precision@4: {precision_golbangE_10:.4f}")
print(f'@K: {golbange_K: .4f}')
# Out:
# Recall@4: 0.0002
# Precision@4: 0.0006
# @K:  0.0006

# %% [markdown]
# ## 개인 확인

# %%
cast_name = "양준모"  # 예시 캐스트 이름
top_n = 10 # 추천할 상위 10개 뮤지컬
recommendations = recommender.recommend_for_cast(cast_name, top_n)
print(recommendations)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
#      cast                                              title     score
# 3477  양준모  창작뮤지컬어워드 NEXT, 니에블라 & 죽거나, 죽이거나 & Behind the Moon  0.999974
# 2796  양준모                                       연남동 빙굴빙굴 빨래방  0.999974
# 3836  양준모                       틱틱붐: LOUDER THAN WORDS! 쇼케이스  0.999967
# 3459  양준모                                  집들이 콘서트, #38. 로기수  0.999965
# 615   양준모                                     나도 해피엔딩을 쓰고 싶어  0.999964
# 207   양준모                      Via Air Mail (비아 에어 메일) [대학로]  0.999964
# 4065  양준모                                                헤드윅  0.999964
# 3347  양준모                    제8회 한국뮤지컬어워즈, 뮤이어(MU:Year) 스테이지  0.999962
# 1638  양준모                                              바톤콘서트  0.999959
# 1059  양준모                                   라이브 콘서트, The 슈또풍  0.999959

# %%
merged_df_4 = recommendations.merge(data, on=['cast', 'title'], how='inner')

# %%
# Filter rows where target == 1 in the data DataFrame
target_1_count_4 = merged_df_4[merged_df_4['target'] == 1].shape[0]

# %%
# Print the count of rows where target == 1
print("Number of matching rows where target is 1:", target_1_count_4)
# Out:
# Number of matching rows where target is 1: 0

# %%
merged_df_4
# Out:
# Empty DataFrame
# Columns: [cast, title, score, genre, percentage, ticket_price, target]
# Index: []
